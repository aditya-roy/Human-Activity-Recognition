# %% [markdown]
# # HumanActivityRecognition
#
# <br>
#
#
# This project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
#
# This dataset is collected from 30 persons(referred as subjects in this dataset), performing different activities with a smartphone to their waists. The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone. This experiment was video recorded to label the data manually.
#
# ## How data was recorded
#
# By using the sensors(Gyroscope and accelerometer) in a smartphone, they have captured '3-axial linear acceleration'(_tAcc-XYZ_) from accelerometer and '3-axial angular velocity' (_tGyro-XYZ_) from Gyroscope with several variations.
#
# > prefix 't' in those metrics denotes time.
#
# > suffix 'XYZ' represents 3-axial signals in X , Y, and Z directions.
#
# ### Feature names
#
# 1. These sensor signals are preprocessed by applying noise filters and then sampled in fixed-width windows(sliding windows) of 2.56 seconds each with 50% overlap. ie., each window has 128 readings.
#
# 2. From Each window, a feature vector was obtianed by calculating variables from the time and frequency domain.
# > In our dataset, each datapoint represents a window with different readings
# 3. The accelertion signal was saperated into Body and Gravity acceleration signals(___tBodyAcc-XYZ___ and ___tGravityAcc-XYZ___) using some low pass filter with corner frequecy of 0.3Hz.
#
# 4. After that, the body linear acceleration and angular velocity were derived in time to obtian _jerk signals_ (___tBodyAccJerk-XYZ___ and ___tBodyGyroJerk-XYZ___).
#
# 5. The magnitude of these 3-dimensional signals were calculated using the Euclidian norm. This magnitudes are represented as features with names like _tBodyAccMag_, _tGravityAccMag_, _tBodyAccJerkMag_, _tBodyGyroMag_ and _tBodyGyroJerkMag_.
#
# 6. Finally, We've got frequency domain signals from some of the available signals by applying a FFT (Fast Fourier Transform). These signals obtained were labeled with ___prefix 'f'___ just like original signals with ___prefix 't'___. These signals are labeled as ___fBodyAcc-XYZ___, ___fBodyGyroMag___ etc.,.
#
# 7. These are the signals that we got so far.
# 	+ tBodyAcc-XYZ
# 	+ tGravityAcc-XYZ
# 	+ tBodyAccJerk-XYZ
# 	+ tBodyGyro-XYZ
# 	+ tBodyGyroJerk-XYZ
# 	+ tBodyAccMag
# 	+ tGravityAccMag
# 	+ tBodyAccJerkMag
# 	+ tBodyGyroMag
# 	+ tBodyGyroJerkMag
# 	+ fBodyAcc-XYZ
# 	+ fBodyAccJerk-XYZ
# 	+ fBodyGyro-XYZ
# 	+ fBodyAccMag
# 	+ fBodyAccJerkMag
# 	+ fBodyGyroMag
# 	+ fBodyGyroJerkMag
#
# 8. We can esitmate some set of variables from the above signals. ie., We will estimate the following properties on each and every signal that we recoreded so far.
#
# 	+ ___mean()___: Mean value
# 	+ ___std()___: Standard deviation
# 	+ ___mad()___: Median absolute deviation
# 	+ ___max()___: Largest value in array
# 	+ ___min()___: Smallest value in array
# 	+ ___sma()___: Signal magnitude area
# 	+ ___energy()___: Energy measure. Sum of the squares divided by the number of values.
# 	+ ___iqr()___: Interquartile range
# 	+ ___entropy()___: Signal entropy
# 	+ ___arCoeff()___: Autorregresion coefficients with Burg order equal to 4
# 	+ ___correlation()___: correlation coefficient between two signals
# 	+ ___maxInds()___: index of the frequency component with largest magnitude
# 	+ ___meanFreq()___: Weighted average of the frequency components to obtain a mean frequency
# 	+ ___skewness()___: skewness of the frequency domain signal
# 	+ ___kurtosis()___: kurtosis of the frequency domain signal
# 	+ ___bandsEnergy()___: Energy of a frequency interval within the 64 bins of the FFT of each window.
# 	+ ___angle()___: Angle between to vectors.
#
# 9. We can obtain some other vectors by taking the average of signals in a single window sample. These are used on the angle() variable'
# `
# 	+ gravityMean
# 	+ tBodyAccMean
# 	+ tBodyAccJerkMean
# 	+ tBodyGyroMean
# 	+ tBodyGyroJerkMean
#
#
# ###  Y_Labels(Encoded)
# + In the dataset, Y_labels are represented as numbers from 1 to 6 as their identifiers.
#
# 	- WALKING as __1__
# 	- WALKING_UPSTAIRS as __2__
# 	- WALKING_DOWNSTAIRS as __3__
# 	- SITTING as __4__
# 	- STANDING as __5__
# 	- LAYING as __6__
#
# ## Train and test data were saperated
#  - The readings from ___70%___ of the volunteers were taken as ___trianing data___ and remaining ___30%___ subjects recordings were taken for ___test data___
#
# ## Data
#
# * All the data is present in 'UCI_HAR_dataset/' folder in present working directory.
#      - Feature names are present in 'UCI_HAR_dataset/features.txt'
#      - ___Train Data___
#          - 'UCI_HAR_dataset/train/X_train.txt'
#          - 'UCI_HAR_dataset/train/subject_train.txt'
#          - 'UCI_HAR_dataset/train/y_train.txt'
#      - ___Test Data___
#          - 'UCI_HAR_dataset/test/X_test.txt'
#          - 'UCI_HAR_dataset/test/subject_test.txt'
#          - 'UCI_HAR_dataset/test/y_test.txt'
#
#
# ## Data Size :
# > 27 MB

# %% [markdown]
# # Quick overview of the dataset :

# %% [markdown]
# * Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.
#
#     1. Walking
#     2. WalkingUpstairs
#     3. WalkingDownstairs
#     4. Standing
#     5. Sitting
#     6. Lying.
#
#
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
#
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings,
#   which has x,y and z components each.
#
# * Gyroscope readings are the measure of angular velocities which has x,y and z components.
#
# * Jerk signals are calculated for BodyAcceleration readings.
#
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
#
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, engerybands,entropy etc., are calculated for each window.
#
# * We get a feature vector of 561 features and these features are given in the dataset.
#
# * Each window of readings is a datapoint of 561 features.
#
# ## Problem Framework
#
# * 30 subjects(volunteers) data is randomly split to 70%(21) test and 30%(7) train data.
# * Each datapoint corresponds one of the 6 Activities.

# %% [markdown]
# ## Problem Statement
#
#  + Given a new datapoint we have to predict the Activity

# %%
import numpy as np
import pandas as pd

# get the features from the file features.txt
features = list()
with open('C:\\Users\\admin\\Downloads\\HumanActivityRecognition\\HAR\\UCI_HAR_Dataset\\features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %% [markdown]
# ## Obtain the  train data

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('C:\\Users\\admin\\Downloads\\HumanActivityRecognition\\HAR\\UCI_HAR_Dataset\\train\\X_train.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_train['subject'] = pd.read_csv('C:\\Users\\admin\\Downloads\\HumanActivityRecognition\\HAR\\UCI_HAR_Dataset\\train\\subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('C:\\Users\\admin\\Downloads\\HumanActivityRecognition\\HAR\\UCI_HAR_Dataset\\train\\y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample()
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\pandas\io\parsers.py:702: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 5748            0.28172           -0.01597          -0.110049
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 5748         -0.992934          -0.99486         -0.995871         -0.993036
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 5748          -0.99374         -0.995424         -0.938318  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 5748                    -0.044692                              0.346509
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 5748                          0.462554                             -0.220584
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 5748               0.66114             -0.558393             -0.442976
#
#       subject  Activity  ActivityName
# 5748       26         6        LAYING
#
# [1 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ## Obtain the  test data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('C:\\Users\\admin\\Downloads\\HumanActivityRecognition\\HAR\\UCI_HAR_Dataset\\test\\X_test.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('C:\\Users\\admin\\Downloads\\HumanActivityRecognition\\HAR\\UCI_HAR_Dataset\\test\\subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('C:\\Users\\admin\\Downloads\\HumanActivityRecognition\\HAR\\UCI_HAR_Dataset\\test\\y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 2184           0.251755          -0.025435          -0.156882
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 2184         -0.414756         -0.233918         -0.241428         -0.468035
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 2184         -0.279627         -0.298286         -0.239177  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 2184                    -0.030205                              0.851773
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 2184                          0.994866                             -0.541302
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 2184             -0.574847              0.305313              0.228297
#
#       subject  Activity      ActivityName
# 2184       18         2  WALKING_UPSTAIRS
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ## 3. Check for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# > We have got almost same number of reading from all the subjects

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observation
# > Our data is well balanced (almost)

# %% [markdown]
# ## 4. Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## 5. Save this dataframe in a csv files

# %%
train.to_csv('UCI_HAR_Dataset/csv_files/train.csv', index=False)
test.to_csv('UCI_HAR_Dataset/csv_files/test.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# "___Without domain knowledge EDA has no meaning, without EDA a problem has no soul.___"

# %% [markdown]
# ### 1. Featuring Engineering from Domain Knowledge

# %% [markdown]
# + __Static and Dynamic Activities__
#
#     - In static activities (sit, stand, lie down) motion information will not be very useful.
# 	- In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 2. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __ Observations__:
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### 4. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __ Observations__:
# * If angleX,gravityMean > 0 then Activity is Laying.
# * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# # Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.298s...
# [t-SNE] Computed neighbors for 7352 samples in 47.662s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635855
# [t-SNE] Computed conditional probabilities in 0.079s
# [t-SNE] Iteration 50: error = 124.6674271, gradient norm = 0.0279990 (50 iterations in 5.497s)
# [t-SNE] Iteration 100: error = 106.7509003, gradient norm = 0.0285594 (50 iterations in 3.428s)
# [t-SNE] Iteration 150: error = 100.5472031, gradient norm = 0.0219381 (50 iterations in 2.928s)
# [t-SNE] Iteration 200: error = 97.2248459, gradient norm = 0.0142265 (50 iterations in 2.750s)
# [t-SNE] Iteration 250: error = 94.9740524, gradient norm = 0.0124886 (50 iterations in 2.739s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 94.974052
# [t-SNE] Iteration 300: error = 4.1115170, gradient norm = 0.0015581 (50 iterations in 2.521s)
# [t-SNE] Iteration 350: error = 3.2050474, gradient norm = 0.0010126 (50 iterations in 2.658s)
# [t-SNE] Iteration 400: error = 2.7767520, gradient norm = 0.0007066 (50 iterations in 2.568s)
# [t-SNE] Iteration 450: error = 2.5138288, gradient norm = 0.0005635 (50 iterations in 2.533s)
# [t-SNE] Iteration 500: error = 2.3302715, gradient norm = 0.0004819 (50 iterations in 2.611s)
# [t-SNE] Iteration 550: error = 2.1926439, gradient norm = 0.0004231 (50 iterations in 2.516s)
# [t-SNE] Iteration 600: error = 2.0832827, gradient norm = 0.0003718 (50 iterations in 2.709s)
# [t-SNE] Iteration 650: error = 1.9939826, gradient norm = 0.0003349 (50 iterations in 2.731s)
# [t-SNE] Iteration 700: error = 1.9186333, gradient norm = 0.0003023 (50 iterations in 2.529s)
# [t-SNE] Iteration 750: error = 1.8537549, gradient norm = 0.0002756 (50 iterations in 2.627s)
# [t-SNE] Iteration 800: error = 1.7971301, gradient norm = 0.0002598 (50 iterations in 2.636s)
# [t-SNE] Iteration 850: error = 1.7472417, gradient norm = 0.0002407 (50 iterations in 2.588s)
# [t-SNE] Iteration 900: error = 1.7025458, gradient norm = 0.0002255 (50 iterations in 2.606s)
# [t-SNE] Iteration 950: error = 1.6626042, gradient norm = 0.0002114 (50 iterations in 2.660s)
# [t-SNE] Iteration 1000: error = 1.6262361, gradient norm = 0.0002005 (50 iterations in 2.659s)
# [t-SNE] KL divergence after 1000 iterations: 1.626236
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\admin\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.256s...
# [t-SNE] Computed neighbors for 7352 samples in 45.088s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.132s
# [t-SNE] Iteration 50: error = 114.0076599, gradient norm = 0.0220887 (50 iterations in 4.548s)
# [t-SNE] Iteration 100: error = 97.7500229, gradient norm = 0.0203321 (50 iterations in 3.148s)
# [t-SNE] Iteration 150: error = 93.2211227, gradient norm = 0.0123866 (50 iterations in 2.890s)
# [t-SNE] Iteration 200: error = 91.1878433, gradient norm = 0.0085312 (50 iterations in 2.848s)
# [t-SNE] Iteration 250: error = 90.0013504, gradient norm = 0.0049194 (50 iterations in 2.752s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.001350
# [t-SNE] Iteration 300: error = 3.5758762, gradient norm = 0.0014599 (50 iterations in 2.642s)
# [t-SNE] Iteration 350: error = 2.8160410, gradient norm = 0.0007451 (50 iterations in 2.685s)
# [t-SNE] Iteration 400: error = 2.4343431, gradient norm = 0.0005280 (50 iterations in 2.657s)
# [t-SNE] Iteration 450: error = 2.2170269, gradient norm = 0.0004039 (50 iterations in 2.653s)
# [t-SNE] Iteration 500: error = 2.0722156, gradient norm = 0.0003318 (50 iterations in 2.763s)
# [t-SNE] Iteration 550: error = 1.9670081, gradient norm = 0.0002848 (50 iterations in 2.727s)
# [t-SNE] Iteration 600: error = 1.8858882, gradient norm = 0.0002491 (50 iterations in 2.889s)
# [t-SNE] Iteration 650: error = 1.8210863, gradient norm = 0.0002197 (50 iterations in 2.784s)
# [t-SNE] Iteration 700: error = 1.7677140, gradient norm = 0.0001971 (50 iterations in 2.868s)
# [t-SNE] Iteration 750: error = 1.7227422, gradient norm = 0.0001808 (50 iterations in 2.823s)
# [t-SNE] Iteration 800: error = 1.6840904, gradient norm = 0.0001654 (50 iterations in 3.036s)
# [t-SNE] Iteration 850: error = 1.6503332, gradient norm = 0.0001537 (50 iterations in 3.056s)
# [t-SNE] Iteration 900: error = 1.6207268, gradient norm = 0.0001425 (50 iterations in 2.660s)
# [t-SNE] Iteration 950: error = 1.5943849, gradient norm = 0.0001348 (50 iterations in 2.656s)
# [t-SNE] Iteration 1000: error = 1.5709407, gradient norm = 0.0001249 (50 iterations in 2.624s)
# [t-SNE] KL divergence after 1000 iterations: 1.570941
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\admin\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.248s...
# [t-SNE] Computed neighbors for 7352 samples in 49.744s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.305s
# [t-SNE] Iteration 50: error = 106.0021973, gradient norm = 0.0149575 (50 iterations in 14.687s)
# [t-SNE] Iteration 100: error = 90.1698608, gradient norm = 0.0116604 (50 iterations in 8.853s)
# [t-SNE] Iteration 150: error = 87.1977921, gradient norm = 0.0048069 (50 iterations in 7.214s)
# [t-SNE] Iteration 200: error = 85.9653320, gradient norm = 0.0040220 (50 iterations in 7.466s)
# [t-SNE] Iteration 250: error = 85.2816391, gradient norm = 0.0038908 (50 iterations in 6.923s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.281639
# [t-SNE] Iteration 300: error = 3.1352391, gradient norm = 0.0013999 (50 iterations in 7.094s)
# [t-SNE] Iteration 350: error = 2.4880893, gradient norm = 0.0006516 (50 iterations in 6.760s)
# [t-SNE] Iteration 400: error = 2.1671028, gradient norm = 0.0004235 (50 iterations in 6.932s)
# [t-SNE] Iteration 450: error = 1.9821211, gradient norm = 0.0003130 (50 iterations in 6.872s)
# [t-SNE] Iteration 500: error = 1.8637251, gradient norm = 0.0002503 (50 iterations in 5.535s)
# [t-SNE] Iteration 550: error = 1.7804252, gradient norm = 0.0002094 (50 iterations in 4.366s)
# [t-SNE] Iteration 600: error = 1.7179811, gradient norm = 0.0001815 (50 iterations in 3.563s)
# [t-SNE] Iteration 650: error = 1.6690820, gradient norm = 0.0001587 (50 iterations in 3.294s)
# [t-SNE] Iteration 700: error = 1.6295515, gradient norm = 0.0001424 (50 iterations in 3.345s)
# [t-SNE] Iteration 750: error = 1.5968382, gradient norm = 0.0001301 (50 iterations in 3.281s)
# [t-SNE] Iteration 800: error = 1.5694206, gradient norm = 0.0001197 (50 iterations in 4.615s)
# [t-SNE] Iteration 850: error = 1.5462054, gradient norm = 0.0001102 (50 iterations in 6.195s)
# [t-SNE] Iteration 900: error = 1.5260246, gradient norm = 0.0001048 (50 iterations in 6.659s)
# [t-SNE] Iteration 950: error = 1.5084640, gradient norm = 0.0000969 (50 iterations in 6.853s)
# [t-SNE] Iteration 1000: error = 1.4932673, gradient norm = 0.0000913 (50 iterations in 6.513s)
# [t-SNE] KL divergence after 1000 iterations: 1.493267
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\admin\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.518s...
# [t-SNE] Computed neighbors for 7352 samples in 70.937s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.446s
# [t-SNE] Iteration 50: error = 97.8154221, gradient norm = 0.0161615 (50 iterations in 13.790s)
# [t-SNE] Iteration 100: error = 84.0541534, gradient norm = 0.0066022 (50 iterations in 7.804s)
# [t-SNE] Iteration 150: error = 81.9269638, gradient norm = 0.0040383 (50 iterations in 6.901s)
# [t-SNE] Iteration 200: error = 81.1668396, gradient norm = 0.0027362 (50 iterations in 6.401s)
# [t-SNE] Iteration 250: error = 80.7779999, gradient norm = 0.0017852 (50 iterations in 6.757s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.778000
# [t-SNE] Iteration 300: error = 2.6914439, gradient norm = 0.0013027 (50 iterations in 6.772s)
# [t-SNE] Iteration 350: error = 2.1592994, gradient norm = 0.0005750 (50 iterations in 6.228s)
# [t-SNE] Iteration 400: error = 1.9104913, gradient norm = 0.0003474 (50 iterations in 6.686s)
# [t-SNE] Iteration 450: error = 1.7642366, gradient norm = 0.0002496 (50 iterations in 6.311s)
# [t-SNE] Iteration 500: error = 1.6706214, gradient norm = 0.0001937 (50 iterations in 6.674s)
# [t-SNE] Iteration 550: error = 1.6065201, gradient norm = 0.0001582 (50 iterations in 6.471s)
# [t-SNE] Iteration 600: error = 1.5604625, gradient norm = 0.0001368 (50 iterations in 6.521s)
# [t-SNE] Iteration 650: error = 1.5261060, gradient norm = 0.0001199 (50 iterations in 6.872s)
# [t-SNE] Iteration 700: error = 1.4993951, gradient norm = 0.0001082 (50 iterations in 6.459s)
# [t-SNE] Iteration 750: error = 1.4784294, gradient norm = 0.0000988 (50 iterations in 6.947s)
# [t-SNE] Iteration 800: error = 1.4617234, gradient norm = 0.0000922 (50 iterations in 6.481s)
# [t-SNE] Iteration 850: error = 1.4477909, gradient norm = 0.0000861 (50 iterations in 6.527s)
# [t-SNE] Iteration 900: error = 1.4358968, gradient norm = 0.0000814 (50 iterations in 6.694s)
# [t-SNE] Iteration 950: error = 1.4257129, gradient norm = 0.0000779 (50 iterations in 6.632s)
# [t-SNE] Iteration 1000: error = 1.4171162, gradient norm = 0.0000732 (50 iterations in 6.822s)
# [t-SNE] KL divergence after 1000 iterations: 1.417116
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\admin\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.593s...
# [t-SNE] Computed neighbors for 7352 samples in 77.511s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 1.010s
# [t-SNE] Iteration 50: error = 85.8482742, gradient norm = 0.0270915 (50 iterations in 12.083s)
# [t-SNE] Iteration 100: error = 75.7078552, gradient norm = 0.0045396 (50 iterations in 11.805s)
# [t-SNE] Iteration 150: error = 74.7448807, gradient norm = 0.0026325 (50 iterations in 10.738s)
# [t-SNE] Iteration 200: error = 74.3126373, gradient norm = 0.0017573 (50 iterations in 10.331s)
# [t-SNE] Iteration 250: error = 74.1012955, gradient norm = 0.0013150 (50 iterations in 9.728s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.101295
# [t-SNE] Iteration 300: error = 2.1535645, gradient norm = 0.0011831 (50 iterations in 7.565s)
# [t-SNE] Iteration 350: error = 1.7556431, gradient norm = 0.0004852 (50 iterations in 6.654s)
# [t-SNE] Iteration 400: error = 1.5873134, gradient norm = 0.0002820 (50 iterations in 6.726s)
# [t-SNE] Iteration 450: error = 1.4939497, gradient norm = 0.0001901 (50 iterations in 6.803s)
# [t-SNE] Iteration 500: error = 1.4338216, gradient norm = 0.0001390 (50 iterations in 6.568s)
# [t-SNE] Iteration 550: error = 1.3927410, gradient norm = 0.0001112 (50 iterations in 5.582s)
# [t-SNE] Iteration 600: error = 1.3636732, gradient norm = 0.0000927 (50 iterations in 5.355s)
# [t-SNE] Iteration 650: error = 1.3422292, gradient norm = 0.0000845 (50 iterations in 5.389s)
# [t-SNE] Iteration 700: error = 1.3265352, gradient norm = 0.0000743 (50 iterations in 5.698s)
# [t-SNE] Iteration 750: error = 1.3148984, gradient norm = 0.0000668 (50 iterations in 4.648s)
# [t-SNE] Iteration 800: error = 1.3057500, gradient norm = 0.0000640 (50 iterations in 4.492s)
# [t-SNE] Iteration 850: error = 1.2982918, gradient norm = 0.0000596 (50 iterations in 4.671s)
# [t-SNE] Iteration 900: error = 1.2924083, gradient norm = 0.0000574 (50 iterations in 4.696s)
# [t-SNE] Iteration 950: error = 1.2877845, gradient norm = 0.0000568 (50 iterations in 5.697s)
# [t-SNE] Iteration 1000: error = 1.2841567, gradient norm = 0.0000531 (50 iterations in 8.238s)
# [t-SNE] KL divergence after 1000 iterations: 1.284157
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\admin\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
